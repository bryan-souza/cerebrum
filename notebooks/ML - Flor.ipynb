# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers.experimental.preprocessing import Rescaling, RandomFlip, RandomRotation, RandomZoom

print(tf.__version__) # 2.6.0
# Out:
# 2.6.0

# %%
from pathlib import Path

# Obter todas as fotos de caule
path = Path( 'fotos/by_plant/flor' )
img_count = len( list(path.glob('*.jpg')) )

# %%
# Vou usar o seguinte esquema:
# 80% das imagens serão usadas para treinar a ML
# 20% para validar a precisão
batch_size = 10
img_width = 100
img_height = 100

# %%
# Criar dataset para treinamento
train_ds = tf.keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_width, img_height),
    batch_size=batch_size
)
# Out:
# Found 99 files belonging to 5 classes.
# Using 80 files for training.
# 2021-11-01 23:04:22.830750: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-01 23:04:22.833363: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Criar dataset para validação
val_ds = tf.keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_width, img_height),
    batch_size=batch_size
)
# Out:
# Found 99 files belonging to 5 classes.
# Using 19 files for validation.

# %%
class_names = train_ds.class_names
print( class_names )
# Out:
# ['caesalpinia_pulcherrima', 'chamaecrista_desvauxii', 'crotalaria_retusa', 'hymenaea_coubaril', 'leucaena_leucocephala']

# %%
# Remover canal gama RGB (vai basicamente deixar todas as fotos em preto e branco)
normalization_layer = Rescaling(1. / 255)

# %%
# Normalizar imagens
normalized_ds = train_ds.map( lambda x, y: (normalization_layer(x), y) )

# Checar se a imagem agora está normalizada
# obs: uma imagem normalizada deve ter os valores
# dos pixels entre 0.0 e 1.0
image_batch, labels_batch = next( iter(normalized_ds) )
first_image = image_batch[0]
print( np.min(first_image), np.max(first_image) )
# Out:
# 2021-11-01 23:04:24.494310: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 0.058823533 1.0

# %%
# Aumento de dados
# como o dataset de imagens é bem pequeno, vamos aplicar
# técnicas como zoom, espelhar e rotacionar as imagens
# existentes, criando cópias com essas modificações
# para serem inclusas no treinamento
data_augmentation = Sequential([
    RandomFlip("horizontal_and_vertical", input_shape=(img_height, img_width, 3)),
    RandomRotation(0.1),
    RandomZoom(0.1)
])

# Visualização das imagens com modificações
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
# Criação do modelo
num_classes = 5
model = Sequential([
    data_augmentation,
    Rescaling(1./255),
    Conv2D(16, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes)
])

# %%
# Compilar o modelo
model.compile(
    optimizer='adam',
    loss=SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# Exibir resumo do modelo
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 100, 100, 3)       0
# _________________________________________________________________
# rescaling_1 (Rescaling)      (None, 100, 100, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 1,204,005
# Trainable params: 1,204,005
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Treinar o modelo
epochs = 100
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 6s 415ms/step - loss: 1.6993 - accuracy: 0.2000 - val_loss: 1.6405 - val_accuracy: 0.0526
# Epoch 2/100
# 8/8 [==============================] - 3s 275ms/step - loss: 1.5926 - accuracy: 0.2375 - val_loss: 1.6745 - val_accuracy: 0.0526
# Epoch 3/100
# 8/8 [==============================] - 3s 321ms/step - loss: 1.5589 - accuracy: 0.2375 - val_loss: 1.6449 - val_accuracy: 0.0526
# Epoch 4/100
# 8/8 [==============================] - 3s 330ms/step - loss: 1.5340 - accuracy: 0.2750 - val_loss: 1.6248 - val_accuracy: 0.2105
# Epoch 5/100
# 8/8 [==============================] - 2s 283ms/step - loss: 1.4609 - accuracy: 0.3625 - val_loss: 1.5674 - val_accuracy: 0.2632
# Epoch 6/100
# 8/8 [==============================] - 2s 295ms/step - loss: 1.3849 - accuracy: 0.4750 - val_loss: 1.4171 - val_accuracy: 0.3158
# Epoch 7/100
# 8/8 [==============================] - 3s 337ms/step - loss: 1.2802 - accuracy: 0.5500 - val_loss: 1.4301 - val_accuracy: 0.4211
# Epoch 8/100
# 8/8 [==============================] - 3s 371ms/step - loss: 1.1559 - accuracy: 0.5875 - val_loss: 1.3480 - val_accuracy: 0.5263
# Epoch 9/100
# 8/8 [==============================] - 3s 358ms/step - loss: 0.9766 - accuracy: 0.6375 - val_loss: 1.1367 - val_accuracy: 0.5789
# Epoch 10/100
# 8/8 [==============================] - 3s 333ms/step - loss: 1.0671 - accuracy: 0.6000 - val_loss: 1.1676 - val_accuracy: 0.6316
# Epoch 11/100
# 8/8 [==============================] - 3s 351ms/step - loss: 1.1020 - accuracy: 0.5625 - val_loss: 1.1725 - val_accuracy: 0.4211
# Epoch 12/100
# 8/8 [==============================] - 2s 299ms/step - loss: 0.8723 - accuracy: 0.6500 - val_loss: 1.3005 - val_accuracy: 0.5789
# Epoch 13/100
# 8/8 [==============================] - 3s 343ms/step - loss: 0.8045 - accuracy: 0.7375 - val_loss: 0.8649 - val_accuracy: 0.6842
# Epoch 14/100
# 8/8 [==============================] - 3s 360ms/step - loss: 0.6865 - accuracy: 0.7000 - val_loss: 1.1599 - val_accuracy: 0.5789
# Epoch 15/100
# 8/8 [==============================] - 3s 340ms/step - loss: 0.6458 - accuracy: 0.7750 - val_loss: 1.0416 - val_accuracy: 0.5789
# Epoch 16/100
# 8/8 [==============================] - 3s 332ms/step - loss: 0.6220 - accuracy: 0.8250 - val_loss: 1.0634 - val_accuracy: 0.4211
# Epoch 17/100
# 8/8 [==============================] - 2s 305ms/step - loss: 0.6055 - accuracy: 0.7500 - val_loss: 0.9277 - val_accuracy: 0.6842
# Epoch 18/100
# 8/8 [==============================] - 3s 348ms/step - loss: 0.5084 - accuracy: 0.8375 - val_loss: 0.8269 - val_accuracy: 0.6316
# Epoch 19/100
# 8/8 [==============================] - 3s 334ms/step - loss: 0.4052 - accuracy: 0.8750 - val_loss: 0.6461 - val_accuracy: 0.6842
# Epoch 20/100
# 8/8 [==============================] - 3s 333ms/step - loss: 0.3556 - accuracy: 0.8500 - val_loss: 0.5535 - val_accuracy: 0.7895
# Epoch 21/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.3181 - accuracy: 0.9125 - val_loss: 0.4654 - val_accuracy: 0.7368
# Epoch 22/100
# 8/8 [==============================] - 2s 328ms/step - loss: 0.3632 - accuracy: 0.9000 - val_loss: 0.3970 - val_accuracy: 0.7895
# Epoch 23/100
# 8/8 [==============================] - 3s 361ms/step - loss: 0.2837 - accuracy: 0.9125 - val_loss: 0.4669 - val_accuracy: 0.7368
# Epoch 24/100
# 8/8 [==============================] - 3s 356ms/step - loss: 0.2306 - accuracy: 0.9250 - val_loss: 0.3621 - val_accuracy: 0.8421
# Epoch 25/100
# 8/8 [==============================] - 2s 306ms/step - loss: 0.2106 - accuracy: 0.9000 - val_loss: 0.4272 - val_accuracy: 0.7368
# Epoch 26/100
# 8/8 [==============================] - 2s 275ms/step - loss: 0.2036 - accuracy: 0.9250 - val_loss: 0.3050 - val_accuracy: 0.8421
# Epoch 27/100
# 8/8 [==============================] - 2s 269ms/step - loss: 0.1765 - accuracy: 0.9000 - val_loss: 0.2759 - val_accuracy: 0.9474
# Epoch 28/100
# 8/8 [==============================] - 3s 323ms/step - loss: 0.1784 - accuracy: 0.9125 - val_loss: 0.2537 - val_accuracy: 0.8421
# Epoch 29/100
# 8/8 [==============================] - 2s 292ms/step - loss: 0.1357 - accuracy: 0.9625 - val_loss: 0.2355 - val_accuracy: 0.9474
# Epoch 30/100
# 8/8 [==============================] - 2s 297ms/step - loss: 0.1301 - accuracy: 0.9625 - val_loss: 0.1287 - val_accuracy: 0.9474
# Epoch 31/100
# 8/8 [==============================] - 2s 249ms/step - loss: 0.1585 - accuracy: 0.9375 - val_loss: 0.1849 - val_accuracy: 0.9474
# Epoch 32/100
# 8/8 [==============================] - 2s 296ms/step - loss: 0.2012 - accuracy: 0.9125 - val_loss: 0.3029 - val_accuracy: 0.8421
# Epoch 33/100
# 8/8 [==============================] - 2s 292ms/step - loss: 0.2047 - accuracy: 0.9250 - val_loss: 0.3526 - val_accuracy: 0.8421
# Epoch 34/100
# 8/8 [==============================] - 3s 331ms/step - loss: 0.1107 - accuracy: 0.9625 - val_loss: 0.3720 - val_accuracy: 0.7895
# Epoch 35/100
# 8/8 [==============================] - 3s 320ms/step - loss: 0.1504 - accuracy: 0.9500 - val_loss: 0.1656 - val_accuracy: 0.9474
# Epoch 36/100
# 8/8 [==============================] - 3s 335ms/step - loss: 0.1651 - accuracy: 0.9500 - val_loss: 0.6030 - val_accuracy: 0.7368
# Epoch 37/100
# 8/8 [==============================] - 2s 298ms/step - loss: 0.1109 - accuracy: 0.9750 - val_loss: 0.1365 - val_accuracy: 0.9474
# Epoch 38/100
# 8/8 [==============================] - 3s 334ms/step - loss: 0.0902 - accuracy: 0.9375 - val_loss: 0.5519 - val_accuracy: 0.8421
# Epoch 39/100
# 8/8 [==============================] - 2s 261ms/step - loss: 0.1280 - accuracy: 0.9250 - val_loss: 0.3094 - val_accuracy: 0.8947
# Epoch 40/100
# 8/8 [==============================] - 3s 335ms/step - loss: 0.1068 - accuracy: 0.9625 - val_loss: 0.2386 - val_accuracy: 0.8947
# Epoch 41/100
# 8/8 [==============================] - 3s 334ms/step - loss: 0.1046 - accuracy: 0.9500 - val_loss: 0.5316 - val_accuracy: 0.7895
# Epoch 42/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.0932 - accuracy: 0.9750 - val_loss: 0.0909 - val_accuracy: 1.0000
# Epoch 43/100
# 8/8 [==============================] - 2s 309ms/step - loss: 0.0692 - accuracy: 0.9875 - val_loss: 0.1754 - val_accuracy: 0.9474
# Epoch 44/100
# 8/8 [==============================] - 3s 329ms/step - loss: 0.0612 - accuracy: 0.9750 - val_loss: 0.1247 - val_accuracy: 0.9474
# Epoch 45/100
# 8/8 [==============================] - 3s 333ms/step - loss: 0.0663 - accuracy: 0.9750 - val_loss: 0.3242 - val_accuracy: 0.8421
# Epoch 46/100
# 8/8 [==============================] - 2s 260ms/step - loss: 0.0895 - accuracy: 0.9500 - val_loss: 0.1425 - val_accuracy: 0.9474
# Epoch 47/100
# 8/8 [==============================] - 2s 295ms/step - loss: 0.2086 - accuracy: 0.9500 - val_loss: 0.6584 - val_accuracy: 0.7368
# Epoch 48/100
# 8/8 [==============================] - 3s 326ms/step - loss: 0.2676 - accuracy: 0.8875 - val_loss: 0.6640 - val_accuracy: 0.8947
# Epoch 49/100
# 8/8 [==============================] - 3s 344ms/step - loss: 0.1532 - accuracy: 0.9375 - val_loss: 0.3194 - val_accuracy: 0.8947
# Epoch 50/100
# 8/8 [==============================] - 3s 309ms/step - loss: 0.1576 - accuracy: 0.9625 - val_loss: 0.1676 - val_accuracy: 1.0000
# Epoch 51/100
# 8/8 [==============================] - 2s 313ms/step - loss: 0.1260 - accuracy: 0.9375 - val_loss: 0.3837 - val_accuracy: 0.7368
# Epoch 52/100
# 8/8 [==============================] - 3s 321ms/step - loss: 0.1615 - accuracy: 0.9250 - val_loss: 0.1310 - val_accuracy: 1.0000
# Epoch 53/100
# 8/8 [==============================] - 2s 284ms/step - loss: 0.1021 - accuracy: 0.9500 - val_loss: 1.2302 - val_accuracy: 0.6316
# Epoch 54/100
# 8/8 [==============================] - 3s 346ms/step - loss: 0.2197 - accuracy: 0.9000 - val_loss: 0.3753 - val_accuracy: 0.8947
# Epoch 55/100
# 8/8 [==============================] - 3s 342ms/step - loss: 0.1975 - accuracy: 0.9375 - val_loss: 0.1614 - val_accuracy: 0.8947
# Epoch 56/100
# 8/8 [==============================] - 3s 330ms/step - loss: 0.1596 - accuracy: 0.9250 - val_loss: 0.5267 - val_accuracy: 0.7895
# Epoch 57/100
# 8/8 [==============================] - 3s 343ms/step - loss: 0.1503 - accuracy: 0.9375 - val_loss: 0.2588 - val_accuracy: 0.8947
# Epoch 58/100
# 8/8 [==============================] - 3s 321ms/step - loss: 0.0901 - accuracy: 0.9625 - val_loss: 0.2408 - val_accuracy: 0.8947
# Epoch 59/100
# 8/8 [==============================] - 3s 349ms/step - loss: 0.1052 - accuracy: 0.9625 - val_loss: 0.1951 - val_accuracy: 0.9474
# Epoch 60/100
# 8/8 [==============================] - 3s 325ms/step - loss: 0.0580 - accuracy: 0.9875 - val_loss: 0.1876 - val_accuracy: 0.9474
# Epoch 61/100
# 8/8 [==============================] - 3s 331ms/step - loss: 0.0769 - accuracy: 0.9625 - val_loss: 0.3080 - val_accuracy: 0.9474
# Epoch 62/100
# 8/8 [==============================] - 3s 334ms/step - loss: 0.0406 - accuracy: 0.9875 - val_loss: 0.3440 - val_accuracy: 0.8947
# Epoch 63/100
# 8/8 [==============================] - 3s 364ms/step - loss: 0.0360 - accuracy: 0.9875 - val_loss: 0.4353 - val_accuracy: 0.8421
# Epoch 64/100
# 8/8 [==============================] - 2s 306ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9474
# Epoch 65/100
# 8/8 [==============================] - 3s 302ms/step - loss: 0.0524 - accuracy: 0.9750 - val_loss: 0.1812 - val_accuracy: 0.8947
# Epoch 66/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0782 - accuracy: 0.9625 - val_loss: 0.3612 - val_accuracy: 0.7895
# Epoch 67/100
# 8/8 [==============================] - 2s 247ms/step - loss: 0.0686 - accuracy: 0.9750 - val_loss: 0.0981 - val_accuracy: 0.9474
# Epoch 68/100
# 8/8 [==============================] - 2s 304ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9474
# Epoch 69/100
# 8/8 [==============================] - 2s 257ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.8947
# Epoch 70/100
# 8/8 [==============================] - 3s 327ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9474
# Epoch 71/100
# 8/8 [==============================] - 3s 327ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.2511 - val_accuracy: 0.9474
# Epoch 72/100
# 8/8 [==============================] - 3s 319ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 1.0000
# Epoch 73/100
# 8/8 [==============================] - 3s 381ms/step - loss: 0.1629 - accuracy: 0.9500 - val_loss: 0.2218 - val_accuracy: 0.8947
# Epoch 74/100
# 8/8 [==============================] - 3s 320ms/step - loss: 0.1417 - accuracy: 0.9750 - val_loss: 0.5437 - val_accuracy: 0.8421
# Epoch 75/100
# 8/8 [==============================] - 2s 249ms/step - loss: 0.1051 - accuracy: 0.9750 - val_loss: 0.4356 - val_accuracy: 0.7895
# Epoch 76/100
# 8/8 [==============================] - 3s 333ms/step - loss: 0.1603 - accuracy: 0.9500 - val_loss: 0.5574 - val_accuracy: 0.7368
# Epoch 77/100
# 8/8 [==============================] - 2s 308ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.8947
# Epoch 78/100
# 8/8 [==============================] - 2s 312ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.3025 - val_accuracy: 0.8421
# Epoch 79/100
# 8/8 [==============================] - 2s 289ms/step - loss: 0.0489 - accuracy: 0.9750 - val_loss: 0.2220 - val_accuracy: 0.8421
# Epoch 80/100
# 8/8 [==============================] - 2s 298ms/step - loss: 0.0243 - accuracy: 0.9875 - val_loss: 0.1054 - val_accuracy: 0.9474
# Epoch 81/100
# 8/8 [==============================] - 2s 291ms/step - loss: 0.0725 - accuracy: 0.9875 - val_loss: 0.3941 - val_accuracy: 0.8421
# Epoch 82/100
# 8/8 [==============================] - 2s 311ms/step - loss: 0.0520 - accuracy: 0.9750 - val_loss: 0.0953 - val_accuracy: 0.9474
# Epoch 83/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0432 - accuracy: 0.9875 - val_loss: 0.2159 - val_accuracy: 0.8947
# Epoch 84/100
# 8/8 [==============================] - 3s 339ms/step - loss: 0.0596 - accuracy: 0.9750 - val_loss: 0.1884 - val_accuracy: 0.8421
# Epoch 85/100
# 8/8 [==============================] - 2s 278ms/step - loss: 0.0864 - accuracy: 0.9375 - val_loss: 0.2108 - val_accuracy: 0.8421
# Epoch 86/100
# 8/8 [==============================] - 3s 329ms/step - loss: 0.2041 - accuracy: 0.9375 - val_loss: 0.5499 - val_accuracy: 0.7895
# Epoch 87/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.0804 - accuracy: 0.9500 - val_loss: 0.2055 - val_accuracy: 0.9474
# Epoch 88/100
# 8/8 [==============================] - 3s 327ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.8252 - val_accuracy: 0.7368
# Epoch 89/100
# 8/8 [==============================] - 3s 389ms/step - loss: 0.0661 - accuracy: 0.9500 - val_loss: 0.2126 - val_accuracy: 0.8947
# Epoch 90/100
# 8/8 [==============================] - 3s 367ms/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 0.1227 - val_accuracy: 0.8947
# Epoch 91/100
# 8/8 [==============================] - 3s 338ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.3377 - val_accuracy: 0.8421
# Epoch 92/100
# 8/8 [==============================] - 3s 312ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.0471 - val_accuracy: 1.0000
# Epoch 93/100
# 8/8 [==============================] - 3s 336ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 94/100
# 8/8 [==============================] - 3s 305ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.8947
# Epoch 95/100
# 8/8 [==============================] - 3s 310ms/step - loss: 0.0673 - accuracy: 0.9750 - val_loss: 0.0848 - val_accuracy: 1.0000
# Epoch 96/100
# 8/8 [==============================] - 3s 348ms/step - loss: 0.0671 - accuracy: 0.9625 - val_loss: 1.7452 - val_accuracy: 0.6316
# Epoch 97/100
# 8/8 [==============================] - 3s 310ms/step - loss: 0.1478 - accuracy: 0.9375 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 98/100
# 8/8 [==============================] - 3s 365ms/step - loss: 0.0388 - accuracy: 1.0000 - val_loss: 0.9048 - val_accuracy: 0.8421
# Epoch 99/100
# 8/8 [==============================] - 3s 363ms/step - loss: 0.2482 - accuracy: 0.9250 - val_loss: 1.0701 - val_accuracy: 0.6316
# Epoch 100/100
# 8/8 [==============================] - 3s 307ms/step - loss: 0.5439 - accuracy: 0.8625 - val_loss: 1.2978 - val_accuracy: 0.6842

# %%
# Estatisticas sobre o treinamento e validação
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

# Plotar gráficos de precisão e perda
plt.figure( figsize=(16, 8) )
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Precisão do Treinamento')
plt.plot(epochs_range, val_acc, label='Precisão da Validação')
plt.legend(loc='lower right')
plt.title('Precisão do Treinamento e Validação')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Perda do Treinamento')
plt.plot(epochs_range, val_loss, label='Perda da Validação')
plt.legend(loc='upper right')
plt.title('Perda do Treinamento e Validação')
plt.show()

# %%
# Testar a ML
# aqui estou usando 4 imagens, uma para cada classe, removidas da pasta 'fotos'
# para verificar se a ML realmente funciona
img = tf.keras.utils.load_img(
    'fotos/testes/FlorCR20.jpg', target_size=(img_width, img_height)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.softmax( predictions[0] )
print( f"Essa imagem provavelmente pertence à classe '{ class_names[ np.argmax(score) ] }' com uma confiança de {(100 * np.max(score)):.2f}%" )
# Out:
# Essa imagem provavelmente pertence à classe 'crotalaria_retusa' com uma confiança de 98.32%

# %%
# Exportar o modelo
from pathlib import Path
ROOT_DIR = Path('..').resolve()
MODELS_PATH = Path( ROOT_DIR, 'models' )
MODEL_PATH = Path( MODELS_PATH, 'flor.h5' )

model.save( MODEL_PATH )
