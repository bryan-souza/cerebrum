# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers.experimental.preprocessing import Rescaling, RandomFlip, RandomRotation, RandomZoom

print(tf.__version__) # 2.8.0
# Out:
# 2.8.0

# %%
from pathlib import Path

# Obter todas as fotos de caule
rootPath = Path('..').resolve()
photosPath = Path(rootPath, 'fotos' )
plantPath = Path(photosPath, 'by_plant' )
florPath = Path(plantPath, 'flor' )
img_count = len(list(florPath.glob('**/*.jpg')))
print(img_count)
# Out:
# 99

# %%
# Vou usar o seguinte esquema:
# 80% das imagens serão usadas para treinar a ML
# 20% para validar a precisão
batch_size = 10
img_width = 100
img_height = 100

# %%
# Criar dataset para treinamento
train_ds = tf.keras.utils.image_dataset_from_directory(
    florPath,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_width, img_height),
    batch_size=batch_size
)
# Out:
# Found 99 files belonging to 5 classes.
# Using 80 files for training.

# %%
# Criar dataset para validação
val_ds = tf.keras.utils.image_dataset_from_directory(
    florPath,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_width, img_height),
    batch_size=batch_size
)
# Out:
# Found 99 files belonging to 5 classes.
# Using 19 files for validation.

# %%
class_names = train_ds.class_names
print( class_names )
# Out:
# ['caesalpinia_pulcherrima', 'chamaecrista_desvauxii', 'crotalaria_retusa', 'hymenaea_coubaril', 'leucaena_leucocephala']

# %%
# Remover canal gama RGB (vai basicamente deixar todas as fotos em preto e branco)
normalization_layer = Rescaling(1. / 255)

# %%
# Normalizar imagens
normalized_ds = train_ds.map( lambda x, y: (normalization_layer(x), y) )

# Checar se a imagem agora está normalizada
# obs: uma imagem normalizada deve ter os valores
# dos pixels entre 0.0 e 1.0
image_batch, labels_batch = next( iter(normalized_ds) )
first_image = image_batch[0]
print( np.min(first_image), np.max(first_image) )
# Out:
# 0.058823533 1.0

# %%
# Aumento de dados
# como o dataset de imagens é bem pequeno, vamos aplicar
# técnicas como zoom, espelhar e rotacionar as imagens
# existentes, criando cópias com essas modificações
# para serem inclusas no treinamento
data_augmentation = Sequential([
    RandomFlip("horizontal_and_vertical", input_shape=(img_height, img_width, 3)),
    RandomRotation(0.1),
    RandomZoom(0.1)
])

# Visualização das imagens com modificações
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
# Criação do modelo
num_classes = 5
model = Sequential([
    data_augmentation,
    Rescaling(1./255),
    Conv2D(16, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes)
])

# %%
# Compilar o modelo
model.compile(
    optimizer='adam',
    loss=SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# Exibir resumo do modelo
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 100, 100, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 100, 100, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,204,005
# Trainable params: 1,204,005
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Treinar o modelo
epochs = 100
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 99ms/step - loss: 1.8145 - accuracy: 0.1375 - val_loss: 1.6383 - val_accuracy: 0.1053
# Epoch 2/100
# 8/8 [==============================] - 1s 89ms/step - loss: 1.5947 - accuracy: 0.2500 - val_loss: 1.6274 - val_accuracy: 0.0526
# Epoch 3/100
# 8/8 [==============================] - 1s 88ms/step - loss: 1.5691 - accuracy: 0.2375 - val_loss: 1.6150 - val_accuracy: 0.0526
# Epoch 4/100
# 8/8 [==============================] - 1s 85ms/step - loss: 1.5252 - accuracy: 0.2750 - val_loss: 1.5442 - val_accuracy: 0.2105
# Epoch 5/100
# 8/8 [==============================] - 1s 89ms/step - loss: 1.4008 - accuracy: 0.3875 - val_loss: 1.4170 - val_accuracy: 0.3158
# Epoch 6/100
# 8/8 [==============================] - 1s 90ms/step - loss: 1.2454 - accuracy: 0.4250 - val_loss: 1.3073 - val_accuracy: 0.5263
# Epoch 7/100
# 8/8 [==============================] - 1s 97ms/step - loss: 1.2404 - accuracy: 0.5000 - val_loss: 1.4398 - val_accuracy: 0.3684
# Epoch 8/100
# 8/8 [==============================] - 1s 83ms/step - loss: 1.0598 - accuracy: 0.6250 - val_loss: 1.1279 - val_accuracy: 0.5789
# Epoch 9/100
# 8/8 [==============================] - 1s 85ms/step - loss: 0.9376 - accuracy: 0.7250 - val_loss: 0.9666 - val_accuracy: 0.5789
# Epoch 10/100
# 8/8 [==============================] - 1s 89ms/step - loss: 0.9924 - accuracy: 0.6250 - val_loss: 1.0177 - val_accuracy: 0.5789
# Epoch 11/100
# 8/8 [==============================] - 1s 85ms/step - loss: 0.8851 - accuracy: 0.6375 - val_loss: 0.9476 - val_accuracy: 0.5789
# Epoch 12/100
# 8/8 [==============================] - 1s 85ms/step - loss: 0.7932 - accuracy: 0.7250 - val_loss: 0.8207 - val_accuracy: 0.6316
# Epoch 13/100
# 8/8 [==============================] - 1s 89ms/step - loss: 0.7494 - accuracy: 0.7375 - val_loss: 0.9764 - val_accuracy: 0.5789
# Epoch 14/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.5912 - accuracy: 0.8125 - val_loss: 0.8111 - val_accuracy: 0.7895
# Epoch 15/100
# 8/8 [==============================] - 1s 82ms/step - loss: 0.7082 - accuracy: 0.7750 - val_loss: 0.7584 - val_accuracy: 0.5263
# Epoch 16/100
# 8/8 [==============================] - 1s 89ms/step - loss: 0.5456 - accuracy: 0.8375 - val_loss: 0.9833 - val_accuracy: 0.6316
# Epoch 17/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.6564 - accuracy: 0.7000 - val_loss: 1.2582 - val_accuracy: 0.5789
# Epoch 18/100
# 8/8 [==============================] - 1s 87ms/step - loss: 0.7141 - accuracy: 0.7000 - val_loss: 0.8837 - val_accuracy: 0.6316
# Epoch 19/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.5384 - accuracy: 0.8250 - val_loss: 0.6401 - val_accuracy: 0.7368
# Epoch 20/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.4250 - accuracy: 0.8875 - val_loss: 0.6224 - val_accuracy: 0.8421
# Epoch 21/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.4096 - accuracy: 0.8375 - val_loss: 0.7154 - val_accuracy: 0.6842
# Epoch 22/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.3568 - accuracy: 0.8500 - val_loss: 0.5006 - val_accuracy: 0.8421
# Epoch 23/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.3237 - accuracy: 0.9125 - val_loss: 0.5589 - val_accuracy: 0.7895
# Epoch 24/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.3109 - accuracy: 0.9000 - val_loss: 0.5508 - val_accuracy: 0.7895
# Epoch 25/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2403 - accuracy: 0.9125 - val_loss: 0.5543 - val_accuracy: 0.7895
# Epoch 26/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2017 - accuracy: 0.9500 - val_loss: 0.3556 - val_accuracy: 0.8421
# Epoch 27/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.2689 - accuracy: 0.9125 - val_loss: 0.5922 - val_accuracy: 0.7368
# Epoch 28/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.3295 - accuracy: 0.9125 - val_loss: 0.5844 - val_accuracy: 0.7895
# Epoch 29/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.3185 - accuracy: 0.8875 - val_loss: 0.7930 - val_accuracy: 0.6842
# Epoch 30/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.2325 - accuracy: 0.9500 - val_loss: 0.3909 - val_accuracy: 0.8421
# Epoch 31/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2857 - accuracy: 0.8875 - val_loss: 0.4002 - val_accuracy: 0.8421
# Epoch 32/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1740 - accuracy: 0.9500 - val_loss: 0.4889 - val_accuracy: 0.7895
# Epoch 33/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1033 - accuracy: 0.9750 - val_loss: 0.4027 - val_accuracy: 0.8947
# Epoch 34/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1333 - accuracy: 0.9500 - val_loss: 0.3790 - val_accuracy: 0.8421
# Epoch 35/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0875 - accuracy: 0.9625 - val_loss: 0.4038 - val_accuracy: 0.7895
# Epoch 36/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0692 - accuracy: 0.9750 - val_loss: 0.1991 - val_accuracy: 0.8947
# Epoch 37/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.8421
# Epoch 38/100
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0688 - accuracy: 0.9875 - val_loss: 0.3564 - val_accuracy: 0.8421
# Epoch 39/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1579 - accuracy: 0.9500 - val_loss: 0.5560 - val_accuracy: 0.7368
# Epoch 40/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1012 - accuracy: 0.9500 - val_loss: 0.4598 - val_accuracy: 0.7368
# Epoch 41/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0986 - accuracy: 0.9500 - val_loss: 0.8604 - val_accuracy: 0.6842
# Epoch 42/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1199 - accuracy: 0.9750 - val_loss: 0.7963 - val_accuracy: 0.7895
# Epoch 43/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2748 - accuracy: 0.9250 - val_loss: 0.8500 - val_accuracy: 0.6842
# Epoch 44/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.3643 - accuracy: 0.8500 - val_loss: 0.3721 - val_accuracy: 0.8421
# Epoch 45/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1629 - accuracy: 0.9500 - val_loss: 0.4288 - val_accuracy: 0.8421
# Epoch 46/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1477 - accuracy: 0.9500 - val_loss: 0.2252 - val_accuracy: 0.8947
# Epoch 47/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1126 - accuracy: 0.9500 - val_loss: 0.1594 - val_accuracy: 0.8947
# Epoch 48/100
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0898 - accuracy: 0.9750 - val_loss: 0.4498 - val_accuracy: 0.6842
# Epoch 49/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0650 - accuracy: 0.9750 - val_loss: 0.3161 - val_accuracy: 0.8421
# Epoch 50/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0827 - accuracy: 0.9875 - val_loss: 0.4948 - val_accuracy: 0.8421
# Epoch 51/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0496 - accuracy: 0.9875 - val_loss: 0.7201 - val_accuracy: 0.7895
# Epoch 52/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1338 - accuracy: 0.9375 - val_loss: 0.4775 - val_accuracy: 0.7895
# Epoch 53/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1364 - accuracy: 0.9750 - val_loss: 0.3258 - val_accuracy: 0.8421
# Epoch 54/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1630 - accuracy: 0.9250 - val_loss: 0.5409 - val_accuracy: 0.7895
# Epoch 55/100
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1569 - accuracy: 0.9375 - val_loss: 0.3744 - val_accuracy: 0.7895
# Epoch 56/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1383 - accuracy: 0.9500 - val_loss: 0.4455 - val_accuracy: 0.7895
# Epoch 57/100
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1284 - accuracy: 0.9500 - val_loss: 0.7450 - val_accuracy: 0.7895
# Epoch 58/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0637 - accuracy: 0.9875 - val_loss: 0.2226 - val_accuracy: 0.8947
# Epoch 59/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0617 - accuracy: 0.9750 - val_loss: 0.2391 - val_accuracy: 0.9474
# Epoch 60/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0445 - accuracy: 0.9875 - val_loss: 0.5277 - val_accuracy: 0.7895
# Epoch 61/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0878 - accuracy: 0.9875 - val_loss: 0.2032 - val_accuracy: 0.8947
# Epoch 62/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 0.1368 - val_accuracy: 0.9474
# Epoch 63/100
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0688 - accuracy: 0.9750 - val_loss: 0.1711 - val_accuracy: 0.9474
# Epoch 64/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.7101 - val_accuracy: 0.6316
# Epoch 65/100
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0319 - accuracy: 0.9875 - val_loss: 0.2524 - val_accuracy: 0.8421
# Epoch 66/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2475 - accuracy: 0.9125 - val_loss: 0.2178 - val_accuracy: 0.8947
# Epoch 67/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0863 - accuracy: 0.9750 - val_loss: 0.7487 - val_accuracy: 0.7895
# Epoch 68/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1129 - accuracy: 0.9500 - val_loss: 0.1711 - val_accuracy: 0.8947
# Epoch 69/100
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0772 - accuracy: 0.9625 - val_loss: 1.2375 - val_accuracy: 0.7368
# Epoch 70/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1099 - accuracy: 0.9625 - val_loss: 0.1057 - val_accuracy: 0.9474
# Epoch 71/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0543 - accuracy: 0.9875 - val_loss: 0.2117 - val_accuracy: 0.9474
# Epoch 72/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0383 - accuracy: 0.9875 - val_loss: 0.3019 - val_accuracy: 0.8421
# Epoch 73/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.3094 - val_accuracy: 0.8947
# Epoch 74/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0990 - accuracy: 0.9500 - val_loss: 0.6275 - val_accuracy: 0.7895
# Epoch 75/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9474
# Epoch 76/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0828 - accuracy: 0.9625 - val_loss: 0.4003 - val_accuracy: 0.8421
# Epoch 77/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0639 - accuracy: 0.9750 - val_loss: 0.5734 - val_accuracy: 0.7895
# Epoch 78/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0477 - accuracy: 0.9875 - val_loss: 0.2870 - val_accuracy: 0.8947
# Epoch 79/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9474
# Epoch 80/100
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0306 - accuracy: 0.9875 - val_loss: 0.1831 - val_accuracy: 0.8947
# Epoch 81/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0317 - accuracy: 0.9875 - val_loss: 0.6652 - val_accuracy: 0.7895
# Epoch 82/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.6523 - val_accuracy: 0.8947
# Epoch 83/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1571 - accuracy: 0.9625 - val_loss: 0.6198 - val_accuracy: 0.8421
# Epoch 84/100
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0712 - accuracy: 0.9750 - val_loss: 0.6917 - val_accuracy: 0.9474
# Epoch 85/100
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0661 - accuracy: 0.9875 - val_loss: 0.4598 - val_accuracy: 0.7895
# Epoch 86/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2310 - accuracy: 0.9000 - val_loss: 0.1426 - val_accuracy: 0.9474
# Epoch 87/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2596 - accuracy: 0.9250 - val_loss: 0.7504 - val_accuracy: 0.7368
# Epoch 88/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1528 - accuracy: 0.9625 - val_loss: 0.4971 - val_accuracy: 0.8421
# Epoch 89/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0834 - accuracy: 0.9625 - val_loss: 0.4166 - val_accuracy: 0.8421
# Epoch 90/100
# 8/8 [==============================] - 1s 95ms/step - loss: 0.2070 - accuracy: 0.9500 - val_loss: 0.6690 - val_accuracy: 0.7895
# Epoch 91/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0716 - accuracy: 0.9750 - val_loss: 1.0176 - val_accuracy: 0.7895
# Epoch 92/100
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0924 - accuracy: 0.9875 - val_loss: 0.3246 - val_accuracy: 0.8947
# Epoch 93/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1583 - accuracy: 0.9750 - val_loss: 0.3526 - val_accuracy: 0.8947
# Epoch 94/100
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0801 - accuracy: 0.9625 - val_loss: 0.2625 - val_accuracy: 0.8947
# Epoch 95/100
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0665 - accuracy: 0.9750 - val_loss: 0.1066 - val_accuracy: 0.9474
# Epoch 96/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0952 - accuracy: 0.9625 - val_loss: 0.4390 - val_accuracy: 0.8421
# Epoch 97/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0433 - accuracy: 0.9875 - val_loss: 0.8193 - val_accuracy: 0.8421
# Epoch 98/100
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1547 - accuracy: 0.9500 - val_loss: 0.3002 - val_accuracy: 0.8947
# Epoch 99/100
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0316 - accuracy: 0.9875 - val_loss: 0.1498 - val_accuracy: 0.9474
# Epoch 100/100
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0414 - accuracy: 0.9875 - val_loss: 0.1445 - val_accuracy: 0.9474

# %%
# Estatisticas sobre o treinamento e validação
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

# Plotar gráficos de precisão e perda
plt.figure( figsize=(16, 8) )
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Precisão do Treinamento')
plt.plot(epochs_range, val_acc, label='Precisão da Validação')
plt.legend(loc='lower right')
plt.title('Precisão do Treinamento e Validação')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Perda do Treinamento')
plt.plot(epochs_range, val_loss, label='Perda da Validação')
plt.legend(loc='upper right')
plt.title('Perda do Treinamento e Validação')
plt.show()

# %%
# Testar a ML
# aqui estou usando 4 imagens, uma para cada classe, removidas da pasta 'fotos'
# para verificar se a ML realmente funciona
testPath = Path(photosPath, 'testes' )
img = tf.keras.utils.load_img(
    Path(testPath, 'FlorCR20.jpg') , target_size=(img_width, img_height)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.softmax( predictions[0] )
print( f"Essa imagem provavelmente pertence à classe '{ class_names[ np.argmax(score) ] }' com uma confiança de {(100 * np.max(score)):.2f}%" )
# Out:
# Essa imagem provavelmente pertence à classe 'crotalaria_retusa' com uma confiança de 99.38%

# %%
# Exportar o modelo
MODELS_PATH = Path( rootPath , 'models' )
MODEL_PATH = Path( MODELS_PATH , 'flor.h5' )

model.save( MODEL_PATH )
